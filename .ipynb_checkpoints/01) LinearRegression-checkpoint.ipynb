# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file=pd.read_csv("D:\Acmegrade\Files\Salary_Data.csv")
file
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x=file.iloc[:,:-1].values
y=file.iloc[:,-1].values

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872], dtype=int64)

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (24, 1) (6, 1) (24,) (6,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
lr
# Out:
# LinearRegression()

# %%
a=lr.predict(x_test)
a
# Out:
# array([ 88741.21194981,  81231.89012757,  91557.20763315,  61519.92034418,
#         54949.26374972, 114085.17309988])

# %%
from sklearn.metrics import r2_score as rs
acc=rs(y_test,a)
acc
# Out:
# 0.8534632740903223

# %%
final=lr.predict(x)
final
# Out:
# array([ 35237.29396633,  37114.62442189,  38991.95487745,  43685.28101636,
#         45562.61147192,  52133.26806638,  53071.93329416,  54949.26374972,
#         54949.26374972,  59642.58988862,  61519.92034418,  62458.58557196,
#         62458.58557196,  63397.25079974,  67151.91171086,  70906.57262199,
#         72783.90307755,  74661.23353311,  80293.22489979,  81231.89012757,
#         88741.21194981,  91557.20763315,  99066.52945539, 101882.52513874,
#        106575.85127764, 109391.84696098, 114085.17309988, 115023.83832766,
#        121594.49492212, 123471.82537768])

# %%
acc=rs(y,final)
acc
# Out:
# 0.9548763499329227

# %%
from matplotlib.pylab import rcParams
rcParams["figure.figsize"]=15,6

# %%
plt.plot(x,y,label="Orginal value",color="r")
plt.plot(x,final,label="Predicted value",color="g")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend
plt.show()

# %%
file
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
final
# Out:
# array([ 35237.29396633,  37114.62442189,  38991.95487745,  43685.28101636,
#         45562.61147192,  52133.26806638,  53071.93329416,  54949.26374972,
#         54949.26374972,  59642.58988862,  61519.92034418,  62458.58557196,
#         62458.58557196,  63397.25079974,  67151.91171086,  70906.57262199,
#         72783.90307755,  74661.23353311,  80293.22489979,  81231.89012757,
#         88741.21194981,  91557.20763315,  99066.52945539, 101882.52513874,
#        106575.85127764, 109391.84696098, 114085.17309988, 115023.83832766,
#        121594.49492212, 123471.82537768])

# %%
result=pd.DataFrame(final,columns=["Predicted Output"])
result
# Out:
#     Predicted Output
# 0       35237.293966
# 1       37114.624422
# 2       38991.954877
# 3       43685.281016
# 4       45562.611472
# 5       52133.268066
# 6       53071.933294
# 7       54949.263750
# 8       54949.263750
# 9       59642.589889
# 10      61519.920344
# 11      62458.585572
# 12      62458.585572
# 13      63397.250800
# 14      67151.911711
# 15      70906.572622
# 16      72783.903078
# 17      74661.233533
# 18      80293.224900
# 19      81231.890128
# 20      88741.211950
# 21      91557.207633
# 22      99066.529455
# 23     101882.525139
# 24     106575.851278
# 25     109391.846961
# 26     114085.173100
# 27     115023.838328
# 28     121594.494922
# 29     123471.825378

# %%
result=pd.concat([file,result],axis=1)

# %% [raw]
# result

# %%
result
# Out:
#     YearsExperience  Salary  Predicted Output
# 0               1.1   39343      35237.293966
# 1               1.3   46205      37114.624422
# 2               1.5   37731      38991.954877
# 3               2.0   43525      43685.281016
# 4               2.2   39891      45562.611472
# 5               2.9   56642      52133.268066
# 6               3.0   60150      53071.933294
# 7               3.2   54445      54949.263750
# 8               3.2   64445      54949.263750
# 9               3.7   57189      59642.589889
# 10              3.9   63218      61519.920344
# 11              4.0   55794      62458.585572
# 12              4.0   56957      62458.585572
# 13              4.1   57081      63397.250800
# 14              4.5   61111      67151.911711
# 15              4.9   67938      70906.572622
# 16              5.1   66029      72783.903078
# 17              5.3   83088      74661.233533
# 18              5.9   81363      80293.224900
# 19              6.0   93940      81231.890128
# 20              6.8   91738      88741.211950
# 21              7.1   98273      91557.207633
# 22              7.9  101302      99066.529455
# 23              8.2  113812     101882.525139
# 24              8.7  109431     106575.851278
# 25              9.0  105582     109391.846961
# 26              9.5  116969     114085.173100
# 27              9.6  112635     115023.838328
# 28             10.3  122391     121594.494922
# 29             10.5  121872     123471.825378

# %%
result["Difference"]=result["Salary"]-result["Predicted Output"]

# %%
result
# Out:
#     YearsExperience  Salary  Predicted Output    Difference
# 0               1.1   39343      35237.293966   4105.706034
# 1               1.3   46205      37114.624422   9090.375578
# 2               1.5   37731      38991.954877  -1260.954877
# 3               2.0   43525      43685.281016   -160.281016
# 4               2.2   39891      45562.611472  -5671.611472
# 5               2.9   56642      52133.268066   4508.731934
# 6               3.0   60150      53071.933294   7078.066706
# 7               3.2   54445      54949.263750   -504.263750
# 8               3.2   64445      54949.263750   9495.736250
# 9               3.7   57189      59642.589889  -2453.589889
# 10              3.9   63218      61519.920344   1698.079656
# 11              4.0   55794      62458.585572  -6664.585572
# 12              4.0   56957      62458.585572  -5501.585572
# 13              4.1   57081      63397.250800  -6316.250800
# 14              4.5   61111      67151.911711  -6040.911711
# 15              4.9   67938      70906.572622  -2968.572622
# 16              5.1   66029      72783.903078  -6754.903078
# 17              5.3   83088      74661.233533   8426.766467
# 18              5.9   81363      80293.224900   1069.775100
# 19              6.0   93940      81231.890128  12708.109872
# 20              6.8   91738      88741.211950   2996.788050
# 21              7.1   98273      91557.207633   6715.792367
# 22              7.9  101302      99066.529455   2235.470545
# 23              8.2  113812     101882.525139  11929.474861
# 24              8.7  109431     106575.851278   2855.148722
# 25              9.0  105582     109391.846961  -3809.846961
# 26              9.5  116969     114085.173100   2883.826900
# 27              9.6  112635     115023.838328  -2388.838328
# 28             10.3  122391     121594.494922    796.505078
# 29             10.5  121872     123471.825378  -1599.825378

# %%
result.to_excel("D:\Acmegrade\Outputs\LinearRegressionop.xlsx")
