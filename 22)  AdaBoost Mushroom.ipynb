# %%
import numpy as np
import pandas as pd

# %%
file=pd.read_csv("D:\\Acmegrade\\Files\\Boost_mushrooms.csv")
file
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for label in file.columns:
    file[label]=LabelEncoder().fit_transform( file[label])

# %%
file
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
y= file.iloc[:,0].values
x=file.iloc[:,2:].values

# %%
x
# Out:
# array([[2, 4, 1, ..., 2, 3, 5],
#        [2, 9, 1, ..., 3, 2, 1],
#        [2, 8, 1, ..., 3, 2, 3],
#        ...,
#        [2, 4, 0, ..., 0, 1, 2],
#        [3, 4, 0, ..., 7, 4, 2],
#        [2, 4, 0, ..., 4, 1, 2]])

# %%
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr
# Out:
# LogisticRegression()

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adaboost=AdaBoostClassifier(base_estimator=lr, n_estimators=400, learning_rate=1)
ad=adaboost.fit(x_train,y_train)
print(ad)
# Out:
# AdaBoostClassifier(base_estimator=LogisticRegression(), learning_rate=1,
#                    n_estimators=400)

# %%
df_pred=ad.predict(x_test)

# %%
df_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,df_pred)
acc
# Out:
# 0.92

# %%
from sklearn.tree import DecisionTreeClassifier as dtc
dt=dtc()
ad1=AdaBoostClassifier(base_estimator=dt, n_estimators=400, learning_rate=1)
ad1
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(), learning_rate=1,
#                    n_estimators=400)

# %%
d_pred2=ad1.fit(x_train,y_train)
df_pred2=d_pred2.predict(x_test)
df_pred2
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
acc=accuracy_score(y_test,df_pred2)
acc
# Out:
# 1.0
