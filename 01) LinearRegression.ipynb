# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file=pd.read_csv("D:\Acmegrade\Files\Salary_Data.csv")
file
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x=file.iloc[:,:-1].values
y=file.iloc[:,-1].values

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872], dtype=int64)

# %%
from sklearn.model_selection import train_test_split as tts
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (24, 1) (6, 1) (24,) (6,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
lr
# Out:
# LinearRegression()

# %%
a=lr.predict(x_test)
a
# Out:
# array([ 40347.4397294 , 125351.77552276,  76238.15928659,  68682.21832718,
#        100794.96740467,  72460.18880689])

# %%
from sklearn.metrics import r2_score as rs
acc=rs(y_test,a)
acc
# Out:
# 0.9680029384921494

# %%
final=lr.predict(x)
final
# Out:
# array([ 36569.46924969,  38458.45448954,  40347.4397294 ,  45069.90282903,
#         46958.88806888,  53570.33640836,  54514.82902829,  56403.81426814,
#         56403.81426814,  61126.27736777,  63015.26260763,  63959.75522755,
#         63959.75522755,  64904.24784748,  68682.21832718,  72460.18880689,
#         74349.17404674,  76238.15928659,  81905.11500615,  82849.60762608,
#         90405.54858549,  93239.02644526, 100794.96740467, 103628.44526445,
#        108350.90836408, 111184.38622386, 115906.84932349, 116851.34194342,
#        123462.7902829 , 125351.77552276])

# %%
acc=rs(y,final)
acc
# Out:
# 0.9567769191284439

# %%
from matplotlib.pylab import rcParams
rcParams["figure.figsize"]=15,6

# %%
plt.plot(x,y,label="Orginal value",color="r")
plt.plot(x,final,label="Predicted value",color="g")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend
plt.show()

# %%
file
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
final
# Out:
# array([ 36569.46924969,  38458.45448954,  40347.4397294 ,  45069.90282903,
#         46958.88806888,  53570.33640836,  54514.82902829,  56403.81426814,
#         56403.81426814,  61126.27736777,  63015.26260763,  63959.75522755,
#         63959.75522755,  64904.24784748,  68682.21832718,  72460.18880689,
#         74349.17404674,  76238.15928659,  81905.11500615,  82849.60762608,
#         90405.54858549,  93239.02644526, 100794.96740467, 103628.44526445,
#        108350.90836408, 111184.38622386, 115906.84932349, 116851.34194342,
#        123462.7902829 , 125351.77552276])

# %%
result=pd.DataFrame(final,columns=["Predicted Output"])
result
# Out:
#     Predicted Output
# 0       36569.469250
# 1       38458.454490
# 2       40347.439729
# 3       45069.902829
# 4       46958.888069
# 5       53570.336408
# 6       54514.829028
# 7       56403.814268
# 8       56403.814268
# 9       61126.277368
# 10      63015.262608
# 11      63959.755228
# 12      63959.755228
# 13      64904.247847
# 14      68682.218327
# 15      72460.188807
# 16      74349.174047
# 17      76238.159287
# 18      81905.115006
# 19      82849.607626
# 20      90405.548585
# 21      93239.026445
# 22     100794.967405
# 23     103628.445264
# 24     108350.908364
# 25     111184.386224
# 26     115906.849323
# 27     116851.341943
# 28     123462.790283
# 29     125351.775523

# %%
result=pd.concat([file,result],axis=1)

# %% [raw]
# result

# %%
result
# Out:
#     YearsExperience  Salary  Predicted Output
# 0               1.1   39343      36569.469250
# 1               1.3   46205      38458.454490
# 2               1.5   37731      40347.439729
# 3               2.0   43525      45069.902829
# 4               2.2   39891      46958.888069
# 5               2.9   56642      53570.336408
# 6               3.0   60150      54514.829028
# 7               3.2   54445      56403.814268
# 8               3.2   64445      56403.814268
# 9               3.7   57189      61126.277368
# 10              3.9   63218      63015.262608
# 11              4.0   55794      63959.755228
# 12              4.0   56957      63959.755228
# 13              4.1   57081      64904.247847
# 14              4.5   61111      68682.218327
# 15              4.9   67938      72460.188807
# 16              5.1   66029      74349.174047
# 17              5.3   83088      76238.159287
# 18              5.9   81363      81905.115006
# ...

# %%
result["Difference"]=result["Salary"]-result["Predicted Output"]

# %%
result
# Out:
#     YearsExperience  Salary  Predicted Output    Difference
# 0               1.1   39343      36569.469250   2773.530750
# 1               1.3   46205      38458.454490   7746.545510
# 2               1.5   37731      40347.439729  -2616.439729
# 3               2.0   43525      45069.902829  -1544.902829
# 4               2.2   39891      46958.888069  -7067.888069
# 5               2.9   56642      53570.336408   3071.663592
# 6               3.0   60150      54514.829028   5635.170972
# 7               3.2   54445      56403.814268  -1958.814268
# 8               3.2   64445      56403.814268   8041.185732
# 9               3.7   57189      61126.277368  -3937.277368
# 10              3.9   63218      63015.262608    202.737392
# 11              4.0   55794      63959.755228  -8165.755228
# 12              4.0   56957      63959.755228  -7002.755228
# 13              4.1   57081      64904.247847  -7823.247847
# 14              4.5   61111      68682.218327  -7571.218327
# ...

# %%
result.to_excel("D:\Acmegrade\Outputs\LinearRegressionop.xlsx")

# %%
import pickle
import os

# %%
os.chdir("C:\\Users\\dinot\\OneDrive\\Desktop\\arun")
with open("lr_pickle","wb") as f:
    pickle.dump(lr,f)

# %%
with open("lr_pickle","rb") as f:
    model=pickle.load(f)

# %%
ans=model.predict([[3.5]])

# %%
ans
# Out:
# array([59237.29212792])

# %%
dhanush= "Father name: sundarababu, age: 20, height: Kutta thaan, weight: Ponnu kedaaka thevaiyaana height, Predicted Salary: 1000 p/m, Predicted wife name: actress name, Predicted babies: 3, relationship status: Fight due to unsatisfaction"

# %%
a=input("Enter name to get josiyam")
if a=="dhanush":
    print(dhanush)
# Out:
# Enter name to get josiyamdhanush
# Father name: sundarababu, age: 20, height: Kutta thaan, weight: Ponnu kedaaka thevaiyaana height, Predicted Salary: 1000 p/m, Predicted wife name: actress name, Predicted babies: 3, relationship status: Fight due to unsatisfaction
